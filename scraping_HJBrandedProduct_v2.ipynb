# %%
import requests
from bs4 import BeautifulSoup
from bs4.element import Comment

# %%
import pandas as pd
hj_branded1 = []
for page_number in range(1, 4):
    page_response = requests.get(f'http://www.hexpharmjaya.com/hj-branded?&page={page_number}')
    page_soup = BeautifulSoup(page_response.text, 'html.parser')
    product_names = page_soup.select('.text-uppercase')
    for product_name in product_names:
        row = product_name
        hj_branded1.append(row)
    hj1=pd.DataFrame(hj_branded1, columns=["PRODUCT_NAME"])

# %%
hj_branded2 = []
for page_number in range(1, 4):
    page_response = requests.get(f'http://www.hexpharmjaya.com/hj-branded?&page={page_number}')
    page_soup = BeautifulSoup(page_response.text, 'html.parser')
    product_categorys = page_soup.select('.cat-desc p')
    for product_category in product_categorys:
        row = product_category
        hj_branded2.append(row)
    hj3=pd.DataFrame(hj_branded2, columns=["PRODUCT_CATEGORY"])
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/internals/construction.py:305: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   values = np.array([convert(v) for v in values])

# %%
frame = [ hj1,hj3]
result = pd.concat(frame,axis=1)

# %%
result['PRODUCT'] = 'HJ BRANDED'

# %%
result
# Out:
#      PRODUCT_NAME                  PRODUCT_CATEGORY     PRODUCT
# 0        Bintamox            [Golongan Penicillins]  HJ BRANDED
# 1        Danasone         [Systemic Antiinfectives]  HJ BRANDED
# 2        Daneuron            [Golongan Penicillins]  HJ BRANDED
# 3         Dapyrin       [Allergy and Immune System]  HJ BRANDED
# 4   Hydrocortison            [Golongan Penicillins]  HJ BRANDED
# 5        Lambucid               [Vitamin & Mineral]  HJ BRANDED
# 6       Spasminal                                []  HJ BRANDED
# 7          Stanza          [Central Nervous System]  HJ BRANDED
# 8         Tibigon                                []  HJ BRANDED
# 9        Betablok                 [Dermatologicals]  HJ BRANDED
# 10        Metisol                                []  HJ BRANDED
# 11      Nephrolit         [Gastrointestinal System]  HJ BRANDED
# 12         Skizon                                []  HJ BRANDED
# 13       Albiotin         [Gastrointestinal System]  HJ BRANDED
# ...

# %%
import pandas as pd
hj_generic1 = []
for page_number in range(1, 6):
    page_response = requests.get(f'http://www.hexpharmjaya.com/hj-generik?&page={page_number}')
    page_soup = BeautifulSoup(page_response.text, 'html.parser')
    product_names = page_soup.select('.text-uppercase')
    for product_name in product_names:
        row = product_name
        hj_generic1.append(row)
    hjg1=pd.DataFrame(hj_generic1, columns=["PRODUCT_NAME"])

# %%
hj_generic2 = []
for page_number in range(1, 6):
    page_response = requests.get(f'http://www.hexpharmjaya.com/hj-generik?&page={page_number}')
    page_soup = BeautifulSoup(page_response.text, 'html.parser')
    product_categorys = page_soup.select('.cat-desc p')
    for product_category in product_categorys:
        row = product_category
        hj_generic2.append(row)
    hjg7=pd.DataFrame(hj_generic2, columns=["PRODUCT_CATEGORY"])
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/internals/construction.py:305: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   values = np.array([convert(v) for v in values])

# %%
hjg2
# Out:
#      PRODUCT_NAME                           PRODUCT_CATEGORY     PRODUCT
# 0        Bintamox             <p>Systemic Antiinfectives</p>  HJ BRANDED
# 1        Danasone           <p>Allergy and Immune System</p>  HJ BRANDED
# 2        Daneuron               <p>Vitamin &amp; Mineral</p>  HJ BRANDED
# 3         Dapyrin              <p>Central Nervous System</p>  HJ BRANDED
# 4   Hydrocortison                     <p>Dermatologicals</p>  HJ BRANDED
# 5        Lambucid             <p>Gastrointestinal System</p>  HJ BRANDED
# 6       Spasminal             <p>Gastrointestinal System</p>  HJ BRANDED
# 7          Stanza              <p>Musculoskeletal System</p>  HJ BRANDED
# 8         Tibigon             <p>Systemic Antiinfectives</p>  HJ BRANDED
# 9        Betablok  <p>Cardiovascular &amp; Hematopoietic</p>  HJ BRANDED
# 10        Metisol           <p>Allergy and Immune System</p>  HJ BRANDED
# 11      Nephrolit                <p>Genitourinary System</p>  HJ BRANDED
# ...

# %%
frame = [ hjg1,hjg3]
result2 = pd.concat(frame,axis=1)
result2['PRODUCT'] = 'HJ GENERIK'
result2
# Out:
#               PRODUCT_NAME                            PRODUCT_CATEGORY  \
# 0               Cetirizine                   [Allergy & Immune System]
# 1               Loratadine                   [Allergy & Immune System]
# 2              Amoxicillin                                          []
# 3   Cefoperazone Sulbactam                   [Systemic Antiinfectives]
# 4               Amlodipine    [Cardiovascular & Hematopoietic Systems]
# 5             Atorvastatin    [Cardiovascular & Hematopoietic Systems]
# 6              Glimepiride              [Endocrine & Metabolic System]
# 7       Losartan Potassium    [Cardiovascular & Hematopoietic Systems]
# 8           Mefenamic Acid                   [Musculo-Skeletal System]
# 9       Methylprednisolone                   [Allergy & Immune System]
# 10              Cefotaxime                   [Systemic Antiinfectives]
# 11             Ceftazidime                   [Systemic Antiinfectives]
# ...

# %%
frame = [hjg2, result2]
master = pd.concat(frame)

# %%
master = master.reset_index()
master
# Out:
#     level_0  index          PRODUCT_NAME                  PRODUCT_CATEGORY  \
# 0         0      0              Bintamox    <p>Systemic Antiinfectives</p>
# 1         1      1              Danasone  <p>Allergy and Immune System</p>
# 2         2      2              Daneuron      <p>Vitamin &amp; Mineral</p>
# 3         3      3               Dapyrin     <p>Central Nervous System</p>
# 4         4      4         Hydrocortison            <p>Dermatologicals</p>
# ..      ...    ...                   ...                               ...
# 59       59     37             Meloxicam         [Musculo-Skeletal System]
# 60       60     38     Kalium Diklofenak         [Musculo-Skeletal System]
# 61       61     39            Ketoprofen         [Musculo-Skeletal System]
# 62       62     40             Ketorolac         [Musculo-Skeletal System]
# 63       63     41  Diclofenac Pottasium         [Musculo-Skeletal System]
#
#        PRODUCT
# 0   HJ BRANDED
# 1   HJ BRANDED
# 2   HJ BRANDED
# ...

# %%
master.to_excel('master_HJ.xlsx')

# %%
master = master.drop(columns=['index','level_0'])

# %%
master = master.reset_index()

# %%
master
# Out:
#             PRODUCT_NAME                  PRODUCT_CATEGORY     PRODUCT
# 0               Bintamox    <p>Systemic Antiinfectives</p>  HJ BRANDED
# 1               Danasone  <p>Allergy and Immune System</p>  HJ BRANDED
# 2               Daneuron      <p>Vitamin &amp; Mineral</p>  HJ BRANDED
# 3                Dapyrin     <p>Central Nervous System</p>  HJ BRANDED
# 4          Hydrocortison            <p>Dermatologicals</p>  HJ BRANDED
# ..                   ...                               ...         ...
# 59             Meloxicam         [Musculo-Skeletal System]  HJ GENERIK
# 60     Kalium Diklofenak         [Musculo-Skeletal System]  HJ GENERIK
# 61            Ketoprofen         [Musculo-Skeletal System]  HJ GENERIK
# 62             Ketorolac         [Musculo-Skeletal System]  HJ GENERIK
# 63  Diclofenac Pottasium         [Musculo-Skeletal System]  HJ GENERIK
#
# [64 rows x 3 columns]
